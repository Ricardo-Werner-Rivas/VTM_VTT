# %% [markdown]
# # Locate talents
# For [basic V20 character sheet](https://www.bibliotecaoscura.com/recursos/hojasdepersonaje/Vampiro/B%C3%A1sica%20V20%20Editable.pdf) from [*Biblioteca Oscura*](https://www.bibliotecaoscura.com/).

# %% [markdown]
# ## English

# %% [markdown]
# ### Alertness

# %%
# Alertness 1

# %%
# Alertness 2

# %%
# Alertness 3

# %%
# Alertness 4

# %%
# Alertness 5

# %% [markdown]
# ### Athletics

# %%
# Athletics 1

# %%
# Athletics 2

# %%
# Athletics 3

# %%
# Athletics 4

# %%
# Athletics 5

# %% [markdown]
# ### Awareness

# %%
# Awareness 1

# %%
# Awareness 2

# %%
# Awareness 3

# %%
# Awareness 4

# %%
# Awareness 5

# %% [markdown]
# ### Brawl

# %%
# Brawl 1

# %%
# Brawl 2

# %%
# Brawl 3

# %%
# Brawl 4

# %%
# Brawl 5

# %% [markdown]
# ### Empathy

# %%
# Empathy 1

# %%
# Empathy 2

# %%
# Empathy 3

# %%
# Empathy 4

# %%
# Empathy 5

# %% [markdown]
# ### Expression

# %%
# Expression 1

# %%
# Expression 2

# %%
# Expression 3

# %%
# Expression 4

# %%
# Expression 5

# %% [markdown]
# ### Intimidation

# %%
# Intimidation 1

# %%
# Intimidation 2

# %%
# Intimidation 3

# %%
# Intimidation 4

# %%
# Intimidation 5

# %% [markdown]
# ### Leadership

# %%
# Leadership 1

# %%
# Leadership 2

# %%
# Leadership 3

# %%
# Leadership 4

# %%
# Leadership 5

# %% [markdown]
# ### Streetwise

# %%
# Streetwise 1

# %%
# Streetwise 2

# %%
# Streetwise 3

# %%
# Streetwise 4

# %%
# Streetwise 5

# %% [markdown]
# ### Subterfuge

# %%
# Subterfuge 1

# %%
# Subterfuge 2

# %%
# Subterfuge 3

# %%
# Subterfuge 4

# %%
# Subterfuge 5

# %% [markdown]
# ### Hobby talent

# %%
# Name

# %%
# Level 1

# %%
# Level 2

# %%
# Level 3

# %%
# Level 4

# %%
# Level 5

# %% [markdown]
# ## Spanish

# %% [markdown]
# ### Alertness
# *Alerta*

# %%
# Alertness 1

# %%
# Alertness 2

# %%
# Alertness 3

# %%
# Alertness 4

# %%
# Alertness 5

# %% [markdown]
# ### Athletics
# *Atletismo*

# %%
# Athletics 1

# %%
# Athletics 2

# %%
# Athletics 3

# %%
# Athletics 4

# %%
# Athletics 5

# %% [markdown]
# ### Streetwise
# *Callejeo*

# %%
# Streetwise 1

# %%
# Streetwise 2

# %%
# Streetwise 3

# %%
# Streetwise 4

# %%
# Streetwise 5

# %% [markdown]
# ### Awareness
# *Conciencia*

# %%
# Awareness 1

# %%
# Awareness 2

# %%
# Awareness 3

# %%
# Awareness 4

# %%
# Awareness 5

# %% [markdown]
# ### Empathy
# *Empatía*

# %%
# Empathy 1

# %%
# Empathy 2

# %%
# Empathy 3

# %%
# Empathy 4

# %%
# Empathy 5

# %% [markdown]
# ### Expression
# *Expresión*

# %%
# Expression 1

# %%
# Expression 2

# %%
# Expression 3

# %%
# Expression 4

# %%
# Expression 5

# %% [markdown]
# ### Intimidation
# *Intimidación*

# %%
# Intimidation 1

# %%
# Intimidation 2

# %%
# Intimidation 3

# %%
# Intimidation 4

# %%
# Intimidation 5

# %% [markdown]
# ### Leadership
# *Liderazgo*

# %%
# Leadership 1

# %%
# Leadership 2

# %%
# Leadership 3

# %%
# Leadership 4

# %%
# Leadership 5

# %% [markdown]
# ### Brawl
# *Pelea*

# %%
# Brawl 1

# %%
# Brawl 2

# %%
# Brawl 3

# %%
# Brawl 4

# %%
# Brawl 5

# %% [markdown]
# ### Subterfuge
# *Subterfugio*

# %%
# Subterfuge 1

# %%
# Subterfuge 2

# %%
# Subterfuge 3

# %%
# Subterfuge 4

# %%
# Subterfuge 5

# %% [markdown]
# ### Hobby talent
# *Talento afición*

# %%
# Name

# %%
# Level 1

# %%
# Level 2

# %%
# Level 3

# %%
# Level 4

# %%
# Level 5
